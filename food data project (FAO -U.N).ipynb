# %%
import pandas as pd

# %%
csv_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin1')

# %%
csv_df.to_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', index=False)

# %%
food_data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', error_bad_lines=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8492\1559579737.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   food_data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', error_bad_lines=False)

# %%
food_data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
food_data.groupby('Y2014')['Y2014'].count()
# Out:
# Y2014
# -1796.0      1
# -1631.0      1
# -849.0       2
# -838.0       1
# -685.0       1
#             ..
#  90425.0     1
#  98094.0     1
#  108756.0    1
#  109593.0    1
#  176405.0    1
# Name: Y2014, Length: 4493, dtype: int64

# %%
food_data.groupby('Y2015')['Y2015'].count()
# Out:
# Y2015
# -3161.0      1
# -2152.0      1
# -1284.0      1
# -907.0       1
# -887.0       1
#             ..
#  92443.0     1
#  100835.0    1
#  110798.0    1
#  111663.0    1
#  181137.0    1
# Name: Y2015, Length: 4520, dtype: int64

# %%
food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
food_data.groupby('Y2018')['Y2018'].count()
# Out:
# Y2018
# -3396.0      1
# -2450.0      1
# -2156.0      2
# -1445.0      1
# -1442.0      1
#             ..
#  98424.0     1
#  109224.0    1
#  117038.0    1
#  118172.0    1
#  195875.0    1
# Name: Y2018, Length: 4591, dtype: int64

# %%
food_data.groupby('Element')['Element'].count()
# Out:
# Element
# Domestic supply quantity                  5295
# Export Quantity                           4403
# Fat supply quantity (g/capita/day)        5023
# Feed                                      1319
# Food                                      4941
# Food supply (kcal/capita/day)             5014
# Food supply quantity (kg/capita/yr)       4905
# Import Quantity                           5139
# Losses                                    2009
# Other uses (non-food)                     1732
# Processing                                2010
# Production                                3881
# Protein supply quantity (g/capita/day)    5023
# Residuals                                 4655
# Seed                                       762
# Stock Variation                           4232
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Element, dtype: int64

# %%
food_df1 = food_data.iloc[0:19000].reset_index(drop=True)

# %%
food_df2 = food_data.iloc[19000:].reset_index(drop=True)

# %%
pd.merge(food_df1, food_df2, how="outer")
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food_data.groupby('Item')['Item'].count()
# Out:
# Item
# Alcohol, Non-Food      283
# Alcoholic Beverages    564
# Animal Products        135
# Animal fats            639
# Apples and products    517
#                       ...
# Vegetables, Other      583
# Vegetal Products       135
# Wheat and products     653
# Wine                   497
# Yams                   383
# Name: Item, Length: 119, dtype: int64
